# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
username = "xinyao1108"
repository = "python-batch-runner"
git_token = "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"

# https://github.com/Comcast/python-batch-runner.git

# %%
file_add = open("/content/drive/My Drive/Comcast/data_type_search.ipynb", 'r')
body = file_add.read()
line = file_add.readline().strip()
print(body)

# %%
# %whos
# Out:
# Variable        Type             Data/Info
# ------------------------------------------
# all_variables   list             n=32
# body            str              {\n  "nbformat": 4,\n  "n<...>tputs": []\n    }\n  ]\n}
# drive           module           <module 'google.colab.dri<...>s/google/colab/drive.py'>
# file_add        TextIOWrapper    <_io.TextIOWrapper name='<...>ode='r' encoding='UTF-8'>
# inspect         module           <module 'inspect' from '/<...>ib/python3.7/inspect.py'>
# line            str
# myvalue         tuple            n=2
# name            str              var6
# retrieve_name   function         <function retrieve_name at 0x7ff01ebc08c0>
# var2            str              Welcome to geeksforgeeks
# var3            dict             n=2
# var4            int              25
# var5            list             n=5
# var6            tuple            n=2

# %%
import ast
#reference: https://stackoverflow.com/questions/50138060/how-to-get-all-of-the-variables-defined-in-a-python-module-without-imports
file_address = open("/content/drive/MyDrive/Comcast/icmp.py", 'r')

code = file_address.read()

tree = ast.parse(code)

assignments = [
    node
    for node in ast.walk(tree)
    if isinstance(node, ast.Assign)
]
var_lists = []
target_variables = set()
for a in assignments:
    var_list = "{}: {}".format(a, ast.dump(a))
    var_lists.append(var_list)
    print(var_list)
    #for target in a.targets:
      #target_variables.add(target.id)
#print(var_lists)
print("Found {} assignments to these variable names:".format(len(assignments)))
#print(target_variables)
# Out:
# <_ast.Assign object at 0x7f6f34cca610>: Assign(targets=[Name(id='LADDR', ctx=Store())], value=Name(id='LADDR', ctx=Load()))
# <_ast.Assign object at 0x7f6f34ccad50>: Assign(targets=[Name(id='LADDR', ctx=Store())], value=Call(func=Attribute(value=Name(id='socket', ctx=Load()), attr='inet_pton', ctx=Load()), args=[Attribute(value=Name(id='s', ctx=Load()), attr='family', ctx=Load()), Subscript(value=Call(func=Attribute(value=Name(id='s', ctx=Load()), attr='getsockname', ctx=Load()), args=[], keywords=[]), slice=Index(value=Num(n=0)), ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34ccc7d0>: Assign(targets=[Name(id='Echo_Reply', ctx=Store())], value=Num(n=0))
# <_ast.Assign object at 0x7f6f34ccc590>: Assign(targets=[Name(id='Destination_Unreachable', ctx=Store())], value=Num(n=3))
# <_ast.Assign object at 0x7f6f34ccc5d0>: Assign(targets=[Name(id='Echo_Request', ctx=Store())], value=Num(n=8))
# <_ast.Assign object at 0x7f6f34ccc610>: Assign(targets=[Name(id='Time_Exceeded', ctx=Store())], value=Num(n=11))
# <_ast.Assign object at 0x7f6f34ccc150>: Assign(targets=[Name(id='Destination_Unreachable', ctx=Store())], value=Num(n=1))
# <_ast.Assign object at 0x7f6f34ccc210>: Assign(targets=[Name(id='Time_Exceeded', ctx=Store())], value=Num(n=3))
# <_ast.Assign object at 0x7f6f34ccc110>: Assign(targets=[Name(id='Echo_Request', ctx=Store())], value=Num(n=128))
# <_ast.Assign object at 0x7f6f34d88ed0>: Assign(targets=[Name(id='Echo_Reply', ctx=Store())], value=Num(n=129))
# <_ast.Assign object at 0x7f6f34cd4ed0>: Assign(targets=[Name(id='countTo', ctx=Store())], value=BinOp(left=BinOp(left=Call(func=Name(id='len', ctx=Load()), args=[Name(id='pkt', ctx=Load())], keywords=[]), op=FloorDiv(), right=Num(n=2)), op=Mult(), right=Num(n=2)))
# <_ast.Assign object at 0x7f6f40a66e10>: Assign(targets=[Tuple(elts=[Name(id='total', ctx=Store()), Name(id='count', ctx=Store())], ctx=Store())], value=Tuple(elts=[Num(n=0), Num(n=0)], ctx=Load()))
# <_ast.Assign object at 0x7f6f34cce290>: Assign(targets=[Tuple(elts=[Name(id='loByte', ctx=Store()), Name(id='hiByte', ctx=Store())], ctx=Store())], value=Tuple(elts=[Num(n=0), Num(n=0)], ctx=Load()))
# <_ast.Assign object at 0x7f6f34bda5d0>: Assign(targets=[Name(id='total', ctx=Store())], value=BinOp(left=BinOp(left=Name(id='total', ctx=Load()), op=RShift(), right=Num(n=16)), op=Add(), right=BinOp(left=Name(id='total', ctx=Load()), op=BitAnd(), right=Num(n=65535))))
# <_ast.Assign object at 0x7f6f34d8c410>: Assign(targets=[Name(id='psh', ctx=Store())], value=BinOp(left=BinOp(left=BinOp(left=Name(id='laddr', ctx=Load()), op=Add(), right=Name(id='raddr', ctx=Load())), op=Add(), right=Call(func=Attribute(value=Name(id='struct', ctx=Load()), attr='pack', ctx=Load()), args=[Str(s='!I'), Call(func=Name(id='len', ctx=Load()), args=[Name(id='pkt', ctx=Load())], keywords=[])], keywords=[])), op=Add(), right=Bytes(s=b'\x00\x00\x00:')))
# <_ast.Assign object at 0x7f6f34c9ce10>: Assign(targets=[Tuple(elts=[Name(id='total', ctx=Store()), Name(id='packet', ctx=Store())], ctx=Store())], value=Tuple(elts=[Num(n=0), BinOp(left=Name(id='psh', ctx=Load()), op=Add(), right=Name(id='pkt', ctx=Load()))], ctx=Load()))
# <_ast.Assign object at 0x7f6f34c9c790>: Assign(targets=[Name(id='num_words', ctx=Store())], value=BinOp(left=Call(func=Name(id='len', ctx=Load()), args=[Name(id='packet', ctx=Load())], keywords=[]), op=FloorDiv(), right=Num(n=2)))
# <_ast.Assign object at 0x7f6f34cd4ad0>: Assign(targets=[Name(id='total', ctx=Store())], value=BinOp(left=BinOp(left=Name(id='total', ctx=Load()), op=RShift(), right=Num(n=16)), op=Add(), right=BinOp(left=Name(id='total', ctx=Load()), op=BitAnd(), right=Num(n=65535))))
# <_ast.Assign object at 0x7f6f34bdbbd0>: Assign(targets=[Name(id='fmt', ctx=Store())], value=Str(s='!BBH4s'))
# <_ast.Assign object at 0x7f6f34bdbc90>: Assign(targets=[Name(id='version', ctx=Store())], value=Num(n=4))
# <_ast.Assign object at 0x7f6f34be9850>: Assign(targets=[Name(id='pkt', ctx=Store())], value=Call(func=Attribute(value=Name(id='struct', ctx=Load()), attr='pack', ctx=Load()), args=[Call(func=Attribute(value=Attribute(value=Name(id='self', ctx=Load()), attr='fmt', ctx=Load()), attr='replace', ctx=Load()), args=[Str(s='H'), Str(s='2s')], keywords=[]), Attribute(value=Name(id='self', ctx=Load()), attr='Type', ctx=Load()), Attribute(value=Name(id='self', ctx=Load()), attr='Code', ctx=Load()), Bytes(s=b'\x00\x00\x00\x00'), Attribute(value=Name(id='self', ctx=Load()), attr='Payload', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f3f76fbd0>: Assign(targets=[Name(id='loByte', ctx=Store())], value=Subscript(value=Name(id='pkt', ctx=Load()), slice=Index(value=Name(id='count', ctx=Load())), ctx=Load()))
# <_ast.Assign object at 0x7f6f34cba150>: Assign(targets=[Name(id='hiByte', ctx=Store())], value=Subscript(value=Name(id='pkt', ctx=Load()), slice=Index(value=BinOp(left=Name(id='count', ctx=Load()), op=Add(), right=Num(n=1))), ctx=Load()))
# <_ast.Assign object at 0x7f6f34cba190>: Assign(targets=[Name(id='loByte', ctx=Store())], value=Subscript(value=Name(id='pkt', ctx=Load()), slice=Index(value=BinOp(left=Name(id='count', ctx=Load()), op=Add(), right=Num(n=1))), ctx=Load()))
# <_ast.Assign object at 0x7f6f34bda0d0>: Assign(targets=[Name(id='hiByte', ctx=Store())], value=Subscript(value=Name(id='pkt', ctx=Load()), slice=Index(value=Name(id='count', ctx=Load())), ctx=Load()))
# <_ast.Assign object at 0x7f6f34be4190>: Assign(targets=[Name(id='packetlen', ctx=Store())], value=Call(func=Name(id='len', ctx=Load()), args=[Name(id='pkt', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34be4a10>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='outbound', ctx=Store())], value=NameConstant(value=False))
# <_ast.Assign object at 0x7f6f34be4b10>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Host', ctx=Store())], value=Name(id='host', ctx=Load()))
# <_ast.Assign object at 0x7f6f34be4c10>: Assign(targets=[Tuple(elts=[Name(id='Type', ctx=Store()), Attribute(value=Name(id='self', ctx=Load()), attr='Code', ctx=Store()), Attribute(value=Name(id='self', ctx=Load()), attr='Checksum', ctx=Store()), Attribute(value=Name(id='self', ctx=Load()), attr='Payload', ctx=Store())], ctx=Store())], value=Call(func=Attribute(value=Name(id='struct', ctx=Load()), attr='unpack', ctx=Load()), args=[Attribute(value=Name(id='self', ctx=Load()), attr='fmt', ctx=Load()), Name(id='pkt', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34be9e10>: Assign(targets=[Name(id='hostaddr', ctx=Store())], value=Call(func=Attribute(value=Name(id='socket', ctx=Load()), attr='inet_pton', ctx=Load()), args=[Attribute(value=Attribute(value=Name(id='self', ctx=Load()), attr='Host', ctx=Load()), attr='family', ctx=Load()), Attribute(value=Attribute(value=Name(id='self', ctx=Load()), attr='Host', ctx=Load()), attr='addr', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34be71d0>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='version', ctx=Store())], value=Num(n=6))
# <_ast.Assign object at 0x7f6f34be72d0>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Type', ctx=Store())], value=Call(func=Name(id='ICMPv6Type', ctx=Load()), args=[Name(id='Type', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34be7450>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Type', ctx=Store())], value=Call(func=Name(id='ICMPv4Type', ctx=Load()), args=[Name(id='Type', ctx=Load())], keywords=[]))
# <_ast.Assign object at 0x7f6f34be7690>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Host', ctx=Store())], value=Name(id='host', ctx=Load()))
# <_ast.Assign object at 0x7f6f34be7790>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='outbound', ctx=Store())], value=NameConstant(value=True))
# <_ast.Assign object at 0x7f6f34be7890>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='fmt', ctx=Store())], value=Call(func=Attribute(value=Attribute(value=Name(id='self', ctx=Load()), attr='fmt', ctx=Load()), attr='replace', ctx=Load()), args=[Str(s='4'), Call(func=Name(id='str', ctx=Load()), args=[BinOp(left=Num(n=4), op=Add(), right=Call(func=Name(id='len', ctx=Load()), args=[Name(id='payload', ctx=Load())], keywords=[]))], keywords=[])], keywords=[]))
# <_ast.Assign object at 0x7f6f34be9250>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Code', ctx=Store())], value=Num(n=0))
# <_ast.Assign object at 0x7f6f34be9350>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Payload', ctx=Store())], value=Name(id='payload', ctx=Load()))
# <_ast.Assign object at 0x7f6f34be9450>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Checksum', ctx=Store())], value=Call(func=Attribute(value=Name(id='self', ctx=Load()), attr='calcChecksum', ctx=Load()), args=[], keywords=[]))
# <_ast.Assign object at 0x7f6f34be4890>: Assign(targets=[Name(id='pkt', ctx=Store())], value=Subscript(value=Name(id='pkt', ctx=Load()), slice=Slice(lower=None, upper=Num(n=8), step=None), ctx=Load()))
# <_ast.Assign object at 0x7f6f34be7e90>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='version', ctx=Store())], value=Num(n=6))
# <_ast.Assign object at 0x7f6f34be7f90>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Type', ctx=Store())], value=Attribute(value=Name(id='ICMPv6Type', ctx=Load()), attr='Echo_Request', ctx=Load()))
# <_ast.Assign object at 0x7f6f34be9110>: Assign(targets=[Attribute(value=Name(id='self', ctx=Load()), attr='Type', ctx=Store())], value=Attribute(value=Name(id='ICMPv4Type', ctx=Load()), attr='Echo_Request', ctx=Load()))
# Found 43 assignments to these variable names:

# %%
import re
import pandas as pd
import numpy as np

astOutPut = pd.DataFrame(columns=['Type'])

all_names = []
for i in var_lists:
  name = re.findall("(?<=Name).+?(?=,)", i, re.DOTALL)
  all_names.append(name)
#print(all_names)

re_allnames = []
for j in all_names:
  re_name = re.findall("(?<=id=').+?(?=')", str(j), re.DOTALL)
  re_allnames.append(re_name)

astOutPut.insert(0, "Variable Name", re_allnames)
print(astOutPut)
astOutPut.to_csv('connvitals_icmp.csv')
# Out:
#                                   Variable Name Type
# 0                                [LADDR, LADDR]  NaN
# 1                         [LADDR, socket, s, s]  NaN
# 2                                  [Echo_Reply]  NaN
# 3                     [Destination_Unreachable]  NaN
# 4                                [Echo_Request]  NaN
# 5                               [Time_Exceeded]  NaN
# 6                     [Destination_Unreachable]  NaN
# 7                               [Time_Exceeded]  NaN
# 8                                [Echo_Request]  NaN
# 9                                  [Echo_Reply]  NaN
# 10                          [countTo, len, pkt]  NaN
# 11                               [total, count]  NaN
# 12                             [loByte, hiByte]  NaN
# 13                        [total, total, total]  NaN
# 14        [psh, laddr, raddr, struct, len, pkt]  NaN
# 15                    [total, packet, psh, pkt]  NaN
# 16                     [num_words, len, packet]  NaN
# 17                        [total, total, total]  NaN
# 18                                        [fmt]  NaN
# 19                                    [version]  NaN
# 20        [pkt, struct, self, self, self, self]  NaN
# 21                         [loByte, pkt, count]  NaN
# 22                         [hiByte, pkt, count]  NaN
# 23                         [loByte, pkt, count]  NaN
# 24                         [hiByte, pkt, count]  NaN
# 25                        [packetlen, len, pkt]  NaN
# 26                                       [self]  NaN
# 27                                 [self, host]  NaN
# 28  [Type, self, self, self, struct, self, pkt]  NaN
# 29               [hostaddr, socket, self, self]  NaN
# 30                                       [self]  NaN
# 31                     [self, ICMPv6Type, Type]  NaN
# 32                     [self, ICMPv4Type, Type]  NaN
# 33                                 [self, host]  NaN
# 34                                       [self]  NaN
# 35              [self, self, str, len, payload]  NaN
# 36                                       [self]  NaN
# 37                              [self, payload]  NaN
# 38                                 [self, self]  NaN
# 39                                   [pkt, pkt]  NaN
# 40                                       [self]  NaN
# 41                           [self, ICMPv6Type]  NaN
# 42                           [self, ICMPv4Type]  NaN

# %%
import pandas as pd
import numpy as np
astOutPut = pd.DataFrame(columns=['Name'])
# print(np.shape(var_lists))
for i in var_lists:
  name =

# %%
import ast
#reference: https://stackoverflow.com/questions/50138060/how-to-get-all-of-the-variables-defined-in-a-python-module-without-imports
file_address = open("/content/drive/MyDrive/Comcast/comcast_rapic_ip_checker.py", 'r')

code = file_address.read()

tree = ast.parse(code)

assignments = [
    node
    for node in ast.walk(tree)
    if isinstance(node, ast.Assign)
]

target_variables = set()
for a in assignments:
    print("{}: {}".format(a, ast.dump(a)))
    for target in a.targets:
        target_variables.add(target.id)

print("Found {} assignments to these variable names:".format(len(assignments)))
print(target_variables)
# Out:
# Module(body=[ImportFrom(module='numba', names=[alias(name='cuda', asname=None)], level=0), Import(names=[alias(name='numpy', asname='np')]), Import(names=[alias(name='time', asname=None), alias(name='sys', asname=None)]), Import(names=[alias(name='operator', asname=None)]), Import(names=[alias(name='argparse', asname=None)]), Import(names=[alias(name='cudf', asname=None)]), Assign(targets=[Name(id='start_time', ctx=Store())], value=Call(func=Attribute(value=Name(id='time', ctx=Load()), attr='time', ctx=Load()), args=[], keywords=[])), Assign(targets=[Name(id='parser', ctx=Store())], value=Call(func=Attribute(value=Name(id='argparse', ctx=Load()), attr='ArgumentParser', ctx=Load()), args=[], keywords=[keyword(arg='description', value=Str(s='A Cuda Python based program to check if a list of input IPs is within a list of target networks.'))])), Expr(value=Call(func=Attribute(value=Name(id='parser', ctx=Load()), attr='add_argument', ctx=Load()), args=[Str(s='-i'), Str(s='--input')], keywords=[keyword(arg='action', value=Str(s='store')), keyword(arg='dest', value=Str(s='input_file')), keyword(arg='help', value=Str(s='Specify Input list file'))])), Expr(value=Call(func=Attribute(value=Name(id='parser', ctx=Load()), attr='add_argument', ctx=Load()), args=[Str(s='-t'), Str(s='--target')], keywords=[keyword(arg='action', value=Str(s='store')), keyword(arg='dest', value=Str(s='target_file')), keyword(arg='help', value=Str(s='Specify Target list file'))])), Expr(value=Call(func=Attribute(value=Name(id='parser', ctx=Load()), attr='add_argument', ctx=Load()), args=[Str(s='-v'), Str(s='--verbose')], keywords=[keyword(arg='action', value=Str(s='store_true')), keyword(arg='dest', value=Str(s='verbosity')), keyword(arg='help', value=Str(s='Verbose Output'))])), If(test=Compare(left=Call(func=Name(id='len', ctx=Load()), args=[Attribute(value=Name(id='sys', ctx=Load()), attr='argv', ctx=Load())], keywords=[]), ops=[Lt()], comparators=[Num(n=2)]), body=[Expr(value=Call(func=Attribute(value=Name(id='parser', ctx=Load()), attr='print_usage', ctx=Load()), args=[], keywords=[])), Expr(value=Call(func=Attribute(value=Name(id='sys', ctx=Load()), attr='exit', ctx=Load()), args=[Num(n=1)], keywords=[]))], orelse=[]), Assign(targets=[Name(id='args', ctx=Store())], value=Call(func=Attribute(value=Name(id='parser', ctx=Load()), attr='parse_args', ctx=Load()), args=[], keywords=[])), Assign(targets=[Name(id='vprint', ctx=Store())], value=IfExp(test=Attribute(value=Name(id='args', ctx=Load()), attr='verbosity', ctx=Load()), body=Name(id='print', ctx=Load()), orelse=Lambda(args=arguments(args=[], vararg=arg(arg='a', annotation=None), kwonlyargs=[], kw_defaults=[], kwarg=arg(arg='k', annotation=None), defaults=[]), body=NameConstant(value=None)))), FunctionDef(name='load_array', args=arguments(args=[arg(arg='filename', annotation=None)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Assign(targets=[Name(id='gdf', ctx=Store())], value=Call(func=Attribute(value=Name(id='cudf', ctx=Load()), attr='read_csv', ctx=Load()), args=[Name(id='filename', ctx=Load())], keywords=[keyword(arg='sep', value=Str(s='.')), keyword(arg='decimal', value=Str(s=',')), keyword(arg='header', value=NameConstant(value=None)), keyword(arg='encoding', value=Str(s='utf-8-sig'))])), Assign(targets=[Name(id='original_frame', ctx=Store())], value=Name(id='gdf', ctx=Load())), Assign(targets=[Name(id='new_cols', ctx=Store())], value=Call(func=Attribute(value=Attribute(value=Subscript(value=Name(id='gdf', ctx=Load()), slice=Index(value=Str(s='3')), ctx=Load()), attr='str', ctx=Load()), attr='split', ctx=Load()), args=[Str(s='/')], keywords=[keyword(arg='n', value=Num(n=1)), keyword(arg='expand', value=NameConstant(value=True))])), Expr(value=Call(func=Attribute(value=Name(id='gdf', ctx=Load()), attr='drop', ctx=Load()), args=[], keywords=[keyword(arg='columns', value=List(elts=[Str(s='3')], ctx=Load())), keyword(arg='inplace', value=NameConstant(value=True))])), Assig ...

# %%
def safe_eval_var_from_file(mod_path, variable, default=None, *, raise_exception=False):
    import ast
    ModuleType = type(ast)
    with open(mod_path, "r", encoding='UTF-8') as file_mod:
        data = file_mod.read()

    try:
        ast_data = ast.parse(data, filename=mod_path)
    except:
        if raise_exception:
            raise
        print("Syntax error 'ast.parse' can't read %r" % mod_path)
        import traceback
        traceback.print_exc()
        ast_data = None

    if ast_data:
        for body in ast_data.body:
            if body.__class__ == ast.Assign:
                if len(body.targets) == 1:
                    if getattr(body.targets[0], "id", "") == variable:
                        try:
                            return ast.literal_eval(body.value)
                        except:
                            if raise_exception:
                                raise
                            print("AST error parsing %r for %r" % (variable, mod_path))
                            import traceback
                            traceback.print_exc()
    return default


fileName = "/content/drive/MyDrive/Comcast/data_type_search.py"

#print(safe_eval_var_from_file(_file_, )
# Example use, read from ourself :)
this_variable = {"Hello": 1.5, 'World': [1, 2, 3], "this is": {'a set'}}
that_variable = safe_eval_var_from_file(fileName, "data_types")

print(this_variable)
print(that_variable)
#assert(this_variable == that_variable)
# Out:
# {'Hello': 1.5, 'World': [1, 2, 3], 'this is': {'a set'}}
# None
